# %%
import pandas as pd
import re

# %%
bob=pd.read_csv("zouch-e3-p2.psd", header=None, sep = r"\n",engine="python")

# %%
bob[0][0:50]
# Out:
# 0                                     ( (CODE <P_158>))
# 1     ( (CODE <heading:edcomment:XCIX_KATHERINE,_LAD...
# 2            ( (CODE {COM:editorial_material_omitted}))
# 3            ( (IP-MAT (NP-VOC (VAN Honored) (N Cosen))
# 4                                                 (, ,)
# 5                                      (NP-SBJ (PRO I))
# 6                                             (MD must)
# 7                                          (VB returne)
# 8                                    (NP-OB2 (PRO you))
# 9                         (NP-OB1 (Q many) (NS thanks))
# 10                                          (PP (P for)
# 11                                          (NP (D the)
# 12                                          (ADJ great)
# 13                                           (NS payns)
# 14                                    (CONJP (CONJ and)
# 15                                       (NX (N care)))
# 16                                                (, ,)
# 17                                    (CP-REL (WNP-1 0)
# 18                                                (C 0)
# 19                           (IP-SUB (NP-SBJ (PRO you))
# 20                                           (HVP have)
# 21                                           (BEN bene)
# 22                                        (VAN pleased)
# 23                               (IP-INF (NP-OB1 *T*-1)
# 24                                              (TO to)
# 25                                            (VB take)
# 26                                           (PP (P in)
# 27                  (NP (NP-POS (PRO$ my) (N$ sonne's))
# 28                                    (N bisnes))))))))
# 29                                               (. .))
# 30                              (ID ZOUCH-E3-P2,158.4))
# 31                         ( (IP-MAT (NP-SBJ (PRO You))
# 32                                            (MD will)
# 33                                 (ADVP-TMP (ADV now))
# 34                                        (VB continue)
# 35                                         (PP (P with)
# 36                                          (NP (D the)
# 37                                    (ADJP (ADJ seame)
# 38                                     (CONJP *ICH*-1))
# 39                                          (N sealle))
# 40                                    (CODE {COM:zeal})
# 41                                   (CONJP-1 (CONJ or)
# 42                                 (NP (ADJR greter))))
# 43                                           (PP (P in)
# 44                         (NP (PRO$ his) (N behalfe)))
# 45                                                (, ,)
# 46                                           (PP (P by)
# 47                                       (NP (N reason)
# 48                                           (PP (P of)
# 49                                         (NP (D that)
# Name: 0, dtype: object

# %%
'(ID ' in bob[0][30]
# Out:
# True

# %%
tokens={}
counta=0;
tokens[counta]=[]
for line in bob[0]:
    tokens[counta].append(line)
    if '(ID ' in line:
        counta+=1;
        tokens[counta]=[]

# %%
tokens
# Out:
# {0: ['( (CODE <P_158>))',
#   '( (CODE <heading:edcomment:XCIX_KATHERINE,_LADY_ZOUCH,_TO_HENRY_OXINDEN>))',
#   '( (CODE {COM:editorial_material_omitted}))',
#   '( (IP-MAT (NP-VOC (VAN Honored) (N Cosen))',
#   '(, ,)',
#   '(NP-SBJ (PRO I))',
#   '(MD must)',
#   '(VB returne)',
#   '(NP-OB2 (PRO you))',
#   '(NP-OB1 (Q many) (NS thanks))',
#   '(PP (P for)',
#   '(NP (D the)',
#   '(ADJ great)',
#   '(NS payns)',
#   '(CONJP (CONJ and)',
#   '(NX (N care)))',
#   '(, ,)',
#   '(CP-REL (WNP-1 0)',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ (PRO you))',
#   '(HVP have)',
#   '(BEN bene)',
#   '(VAN pleased)',
#   '(IP-INF (NP-OB1 *T*-1)',
#   '(TO to)',
#   '(VB take)',
#   '(PP (P in)',
#   "(NP (NP-POS (PRO$ my) (N$ sonne's))",
#   '(N bisnes))))))))',
#   '(. .))',
#   '(ID ZOUCH-E3-P2,158.4))'],
#  1: ['( (IP-MAT (NP-SBJ (PRO You))',
#   '(MD will)',
#   '(ADVP-TMP (ADV now))',
#   '(VB continue)',
#   '(PP (P with)',
#   '(NP (D the)',
#   '(ADJP (ADJ seame)',
#   '(CONJP *ICH*-1))',
#   '(N sealle))',
#   '(CODE {COM:zeal})',
#   '(CONJP-1 (CONJ or)',
#   '(NP (ADJR greter))))',
#   '(PP (P in)',
#   '(NP (PRO$ his) (N behalfe)))',
#   '(, ,)',
#   '(PP (P by)',
#   '(NP (N reason)',
#   '(PP (P of)',
#   '(NP (D that)',
#   '(ADJ neerre)',
#   '(N relacond)',
#   '(CP-REL (WNP-2 (WPRO which))',
#   '(C 0)',
#   '(IP-SUB (NP-OB1 *T*-2)',
#   '(NP-SBJ (PRO you))',
#   '(VBP mention)',
#   '(PP (P in)',
#   '(NP (ADJ youer) (N letter)))))',
#   '(, ,)',
#   '(CP-REL (WPP-3 (WADV+P wherin))',
#   '(C 0)',
#   '(IP-SUB (PP *T*-3)',
#   '(NP-SBJ (PRO hee))',
#   '(HVP hath)',
#   '(VBN ioyned)',
#   '(NP-OB1 (PRO+N himsellfe))',
#   '(PP (RP on)',
#   '(P to)',
#   '(NP (PRO you)))))))))',
#   '(. :))',
#   '(ID ZOUCH-E3-P2,158.5))'],
#  2: ['( (IP-MAT (NP-OB1 (D the)',
#   '(ADJ first)',
#   '(N intellegenc)',
#   '(PP (ADV+P therof)))',
#   '(NP-SBJ (PRO I))',
#   '(DOD did)',
#   '(VB reseve)',
#   '(PP (P from)',
#   '(NP (PRO$+N youeresellfe)))',
#   '(, ;)',
#   '(CP-CAR (WPP-1 (WADV+P whereof))',
#   '(C 0)',
#   '(IP-SUB (PP *T*-1)',
#   '(NP-SBJ (PRO I))',
#   '(VBP confes)',
#   '(ADJP-SPR (NP-MSR (Q+WPRO somewhat))',
#   '(ADJ strange)',
#   '(CONJP (CONJ and)',
#   '(ADJX (ADJ onexpected)))',
#   '(PP (P to)',
#   '(NP (PRO mee))))))',
#   '(. ;))',
#   '(ID ZOUCH-E3-P2,158.6))'],
#  3: ['( (IP-MAT (CONJ butt)',
#   '(ADVP-TMP (ADV now))',
#   '(, ,)',
#   '(PP-LFD (P though)',
#   '(CP-ADV (C 0)',
#   '(IP-SUB (NP-SBJ (PRO I))',
#   '(MD $can)',
#   '(NEG $not)',
#   '(CODE {TEXT:canot})',
#   '(BE bee)',
#   '(ADJP (ADJ unsensible)',
#   '(CP-THT (C that)',
#   '(IP-SUB (NP-SBJ (PRO hee))',
#   '(HVP hath)',
#   '(VBN furgotten)',
#   '(NP-OB1 (PRO mee)',
#   '(NP-PRN (PRO$ his) (N mother)))',
#   '(PP (P in)',
#   '(IP-PPL (NEG not)',
#   '(VAG takeng)',
#   '(NP-OB1 (PRO$ my) (N advise))',
#   '(PP (P in)',
#   '(NP (D a)',
#   '(N meatter)',
#   '(PP (P of)',
#   '(NP (D that) (N weight)))))))))))))',
#   '(, ,)',
#   '(ADVP-RSP (ADV yet))',
#   '(NP-SBJ (PRO I))',
#   '(BEP am)',
#   '(ADJP (ADJ $glad)',
#   '(CP-THT (C that)',
#   '(IP-SUB (NP-SBJ (PRO hee))',
#   '(HVP heath)',
#   '(NEG not)',
#   '(VBN furgutten)',
#   '(NP-OB1 (PRO+N himsellfe))',
#   '(PP (P in)',
#   '(NP (PRO$ his) (N Choyce)))',
#   '(, ,)',
#   '(IP-PPL (HAG haveing)',
#   '(VBN matched)',
#   '(PP (P with)',
#   '(NP (D a)',
#   '(N daughter)',
#   '(PP (P of)',
#   '(NP (PRO$ youers)))',
#   '(CP-REL (WNP-1 (WPRO$ whose)',
#   '(N worth)',
#   '(CONJP (CONJ and)',
#   '(NX (NS abilityes))))',
#   '(C 0)',
#   '(IP-SUB (NP-OB1 *T*-1)',
#   '(NP-SBJ (PRO I))',
#   '(VBP knowe)',
#   '(ADVP (ADVR so)',
#   '(ADV well)',
#   '(, ,)',
#   '(PP (P as)',
#   '(CP-DEG (C that)',
#   '(IP-SUB (NP-SBJ (PRO you))',
#   '(BEP are)',
#   '(ADJP (ADJ able)',
#   '(IP-INF (IP-INF (PP (P with)',
#   '(NP (N ease)))',
#   '(TO to)',
#   '(VB assiste)',
#   '(NP-OB1 (PRO him)))',
#   '(CONJP (CONJ and)',
#   '(IP-INF (TO *)',
#   '(VB goe)',
#   '(RP thorwgh)',
#   '(PP (P in)',
#   '(NP (D the)',
#   '(N recovery)',
#   '(PP (P of)',
#   '(NP (PRO$ his) (N esteate)))',
#   '(CP-REL (WNP-2 (WPRO which))',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ (PRO I))',
#   '(VBP confes)',
#   '(CODE <P_159>)',
#   '(CP-THT (C 0)',
#   '(IP-SUB (NP-SBJ *T*-2)',
#   '(BED was)',
#   '(NP-OB1 (D a)',
#   '(N taske)',
#   '(ADJP (ADJP (NP-MSR (Q+WPRO somewhat))',
#   '(ADVR to)',
#   '(ADJ heard))',
#   '(CONJP (CONJ and)',
#   '(ADJP (ADV very) (ADJ inproper)))',
#   '(PP (P for)',
#   '(NP (D a) (ADJ weake) (N woman)))))))))))',
#   '(, ;)',
#   '(CP-CAR (WPP-3 (WADV+P wherin))',
#   '(C 0)',
#   '(IP-SUB (PP *T*-3)',
#   '(NP-SBJ (PRO I))',
#   '(MD shall)',
#   '(ADVP-TMP (ADV still))',
#   '(DO doo)',
#   '(NP-OB1 (D the)',
#   '(ADJ outmost)',
#   '(CP-REL (WNP-4 0)',
#   '(C that)',
#   '(IP-SUB (NP-SBJ *T*-4)',
#   '(MD shall)',
#   '(VB ley)',
#   '(PP (P in)',
#   '(NP (PRO$ my) (N power))))))))))))))))))))))))',
#   '(. .))',
#   '(ID ZOUCH-E3-P2,159.7))'],
#  4: ['( (IP-MAT (CONJ But)',
#   '(NP-VOC (ADJ good) (N Cosin))',
#   '(NP-SBJ (PRO I))',
#   '(BEP am)',
#   '(ADJP (ADJ confident)',
#   '(CP-THT (C 0)',
#   '(IP-SUB (NP-SBJ (PRO you))',
#   '(BEP are)',
#   '(ADJP (ADJP (ADVR so) (ADJ ingenuous))',
#   '(CONJP (CONJ and)',
#   '(PP (P of)',
#   '(NP (QP (ADVR so)',
#   '(Q much)',
#   '(PP *ICH*-1))',
#   '(N iudgement)',
#   '(PP-1 (P as)',
#   '(CP-DEG (C theat)',
#   '(IP-SUB (NP-SBJ (PRO you))',
#   '(MD will)',
#   '(NEG not)',
#   '(VB conceive)',
#   '(CP-THT (C 0)',
#   '(IP-SUB (NP-SBJ (PRO I))',
#   '(MD can)',
#   '(VB soppose)',
#   '(CP-THT (C 0)',
#   '(IP-SUB (NP-SBJ (PRO$ my) (N husband))',
#   '(MD shulld)',
#   '(VB expend)',
#   '(NP-OB1 (PRO$ his) (N esteat))',
#   '(PP (P for)',
#   '(NP (D a)',
#   '(N sonne)',
#   '(PP (P in)',
#   '(NP (N Leaw)))))',
#   '(, ,)',
#   '(IP-PPL (HAG having)',
#   '(NP-OB1 (ONE one)',
#   '(PP (P of)',
#   '(NP (PRO$ his) (ADJ owen)))))',
#   '(, ,)',
#   '(CP-CAR (WNP-2 (WPRO which))',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ (PRO I))',
#   '(VBP doubt)',
#   '(NEG not)',
#   '(CP-THT (C 0)',
#   '(IP-SUB (NP-OB1 *T*-2)',
#   '(NP-SBJ (PRO you))',
#   '(MD will)',
#   '(VB take)',
#   '(PP (P into)',
#   '(NP (ADJP (ADVR so)',
#   '(ADJ serious)',
#   '(PP *ICH*-3))',
#   '(N consideracon)',
#   '(PP-3 (P as)',
#   '(IP-INF-DEG (TO to)',
#   '(VB afforde)',
#   '(NP-OB1 (Q all)',
#   '(ADJ faitherly)',
#   '(N care)',
#   '(CONJP (CONJ and)',
#   '(NX (N affection))))',
#   '(PP (P towards)',
#   '(NP (PRO him)',
#   '(CP-REL (WNP-4 (WPRO who))',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ *T*-4)',
#   '(BEP is)',
#   '(ADVP-TMP (ADV now))',
#   '(VAN made)',
#   '(IP-SMC (NP-SBJ *T*-4)',
#   '(NP-OB1 (PRO$ $your) (N $sonne)))',
#   '(PP (P by)',
#   '(NP (D a)',
#   '(N decre)',
#   '(, ,)',
#   '(CP-EOP (WNP-5 0)',
#   '(IP-INF (NP-SBJ *T*-5)',
#   '(PP (P as)',
#   '(CP-ADV (WNP-6 0)',
#   '(C 0)',
#   '(IP-SUB (NP-OB1 *T*-6)',
#   '(NP-SBJ (PRO you))',
#   '(VBP write)',
#   '(ADVP (ADV very) (ADV truely)))))',
#   '(, ,)',
#   '(NEG not)',
#   '(TO to)',
#   '(BE be)',
#   '(VAN prevented)))))))))))))))))))))))))))))))',
#   '(. :))',
#   '(ID ZOUCH-E3-P2,159.8))'],
#  5: ['( (IP-MAT (CONJ and)',
#   '(PP (P for)',
#   '(NP (PRO$ my) (N sellfe)))',
#   '(NP-SBJ (PRO I))',
#   '(MD shall)',
#   '(ADVP-TMP (ADV never))',
#   '(BE be)',
#   '(VAG wanting)',
#   '(IP-INF (NP-MSR (ADJP (ADVR as) (ADJ fare))',
#   '(PP (P as)',
#   '(CP-CMP (WQP-1 0)',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ (PRO I))',
#   '(BEP am)',
#   '(ADJP (QP *T*-1)',
#   '(ADJ able))))))',
#   '(TO to)',
#   '(VB performe)',
#   '(NP-OB1 (D the)',
#   '(N part)',
#   '(PP (P of)',
#   '(NP (D a) (N mother)))))',
#   '(. ,))',
#   '(ID ZOUCH-E3-P2,159.9))'],
#  6: ['( (IP-MAT (CONJ and)',
#   '(PP (P for)',
#   '(NP (D the) (ADJ present)))',
#   '(NP-SBJ *con*)',
#   '(MD shall)',
#   '(VB conclude)',
#   '(, ,)',
#   '(PP (P by)',
#   '(NP (PRO$ youer) (ADJ owen) (ADJ good) (N exampele)))',
#   '(, ,)',
#   '(PP (P with)',
#   '(NP (PRO$ my)',
#   '(NS prayers)',
#   '(CP-THT (C that)',
#   '(IP-SUB (NP-SBJ (Q all) (NS blessings))',
#   '(MD meay)',
#   '(BE bee)',
#   '(VAN multyplyed)',
#   '(PP (P opon)',
#   '(NP (PRO thim)',
#   '(QP (Q both))))',
#   '(, ,)',
#   '(CP-CAR (WNP-1 (WPRO which))',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ *T*-1)',
#   '(MD shall)',
#   '(ADVP-TMP (ADV allways))',
#   '(BE bee)',
#   '(NP-OB1 (D the)',
#   '(ADJ fervent)',
#   '(N desier)',
#   '(PP (P of)',
#   '(NP (PRO her)',
#   '(CP-REL (WNP-2 0)',
#   '(C that)',
#   '(IP-SUB (NP-SBJ *T*-2)',
#   '(BEP is)',
#   '(, ,)',
#   '(NP-VOC (ADJ worthy) (N Cosin))',
#   '(, ,)',
#   '(NP-OB1 (PRO$ Youer)',
#   '(ADJ afacnat)',
#   '(N+N kinwomen)',
#   '(CONJP (CONJ and)',
#   '(NX (N sister)))',
#   '(NP-PRN (NPR Zowch)))))))))))))))',
#   '(ID ZOUCH-E3-P2,159.10))'],
#  7: ['( (CODE {COM:postscript_omitted}))',
#   '( (NP-TMP (NPR Setember) (D this) (NUM 28) (NUM 1649))',
#   '(ID ZOUCH-E3-P2,159.12))'],
#  8: []}

# %%
for token in tokens:
    for line in tokens[token]:
        if '(CODE ' not in line and '(ID' not in line:
            print(line)
# Out:
# ( (IP-MAT (NP-VOC (VAN Honored) (N Cosen))
# (, ,)
# (NP-SBJ (PRO I))
# (MD must)
# (VB returne)
# (NP-OB2 (PRO you))
# (NP-OB1 (Q many) (NS thanks))
# (PP (P for)
# (NP (D the)
# (ADJ great)
# (NS payns)
# (CONJP (CONJ and)
# (NX (N care)))
# (, ,)
# (CP-REL (WNP-1 0)
# (C 0)
# (IP-SUB (NP-SBJ (PRO you))
# (HVP have)
# (BEN bene)
# (VAN pleased)
# (IP-INF (NP-OB1 *T*-1)
# (TO to)
# (VB take)
# (PP (P in)
# (NP (NP-POS (PRO$ my) (N$ sonne's))
# (N bisnes))))))))
# (. .))
# ( (IP-MAT (NP-SBJ (PRO You))
# (MD will)
# (ADVP-TMP (ADV now))
# (VB continue)
# (PP (P with)
# (NP (D the)
# (ADJP (ADJ seame)
# (CONJP *ICH*-1))
# (N sealle))
# (CONJP-1 (CONJ or)
# (NP (ADJR greter))))
# (PP (P in)
# (NP (PRO$ his) (N behalfe)))
# (, ,)
# (PP (P by)
# (NP (N reason)
# (PP (P of)
# (NP (D that)
# (ADJ neerre)
# (N relacond)
# (CP-REL (WNP-2 (WPRO which))
# (C 0)
# (IP-SUB (NP-OB1 *T*-2)
# (NP-SBJ (PRO you))
# (VBP mention)
# (PP (P in)
# (NP (ADJ youer) (N letter)))))
# (, ,)
# (CP-REL (WPP-3 (WADV+P wherin))
# (C 0)
# (IP-SUB (PP *T*-3)
# (NP-SBJ (PRO hee))
# (HVP hath)
# (VBN ioyned)
# (NP-OB1 (PRO+N himsellfe))
# (PP (RP on)
# (P to)
# (NP (PRO you)))))))))
# (. :))
# ( (IP-MAT (NP-OB1 (D the)
# (ADJ first)
# (N intellegenc)
# (PP (ADV+P therof)))
# (NP-SBJ (PRO I))
# (DOD did)
# (VB reseve)
# (PP (P from)
# (NP (PRO$+N youeresellfe)))
# (, ;)
# (CP-CAR (WPP-1 (WADV+P whereof))
# (C 0)
# (IP-SUB (PP *T*-1)
# (NP-SBJ (PRO I))
# (VBP confes)
# (ADJP-SPR (NP-MSR (Q+WPRO somewhat))
# (ADJ strange)
# (CONJP (CONJ and)
# (ADJX (ADJ onexpected)))
# (PP (P to)
# (NP (PRO mee))))))
# (. ;))
# ( (IP-MAT (CONJ butt)
# (ADVP-TMP (ADV now))
# (, ,)
# (PP-LFD (P though)
# (CP-ADV (C 0)
# (IP-SUB (NP-SBJ (PRO I))
# (MD $can)
# (NEG $not)
# (BE bee)
# (ADJP (ADJ unsensible)
# (CP-THT (C that)
# (IP-SUB (NP-SBJ (PRO hee))
# (HVP hath)
# (VBN furgotten)
# (NP-OB1 (PRO mee)
# (NP-PRN (PRO$ his) (N mother)))
# (PP (P in)
# (IP-PPL (NEG not)
# (VAG takeng)
# (NP-OB1 (PRO$ my) (N advise))
# (PP (P in)
# (NP (D a)
# (N meatter)
# (PP (P of)
# (NP (D that) (N weight)))))))))))))
# (, ,)
# (ADVP-RSP (ADV yet))
# (NP-SBJ (PRO I))
# (BEP am)
# (ADJP (ADJ $glad)
# (CP-THT (C that)
# (IP-SUB (NP-SBJ (PRO hee))
# (HVP heath)
# (NEG not)
# (VBN furgutten)
# (NP-OB1 (PRO+N himsellfe))
# (PP (P in)
# (NP (PRO$ his) (N Choyce)))
# (, ,)
# (IP-PPL (HAG haveing)
# (VBN matched)
# (PP (P with)
# (NP (D a)
# (N daughter)
# (PP (P of)
# (NP (PRO$ youers)))
# (CP-REL (WNP-1 (WPRO$ whose)
# (N worth)
# (CONJP (CONJ and)
# (NX (NS abilityes))))
# (C 0)
# (IP-SUB (NP-OB1 *T*-1)
# (NP-SBJ (PRO I))
# (VBP knowe)
# (ADVP (ADVR so)
# (ADV well)
# (, ,)
# (PP (P as)
# (CP-DEG (C that)
# (IP-SUB (NP-SBJ (PRO you))
# (BEP are)
# (ADJP (ADJ able)
# (IP-INF (IP-INF (PP (P with)
# (NP (N ease)))
# (TO to)
# (VB assiste)
# (NP-OB1 (PRO him)))
# (CONJP (CONJ and)
# (IP-INF (TO *)
# (VB goe)
# (RP thorwgh)
# (PP (P in)
# (NP (D the)
# (N recovery)
# (PP (P of)
# (NP (PRO$ his) (N esteate)))
# (CP-REL (WNP-2 (WPRO which))
# (C 0)
# (IP-SUB (NP-SBJ (PRO I))
# (VBP confes)
# (CP-THT (C 0)
# (IP-SUB (NP-SBJ *T*-2)
# (BED was)
# (NP-OB1 (D a)
# (N taske)
# (ADJP (ADJP (NP-MSR (Q+WPRO somewhat))
# (ADVR to)
# (ADJ heard))
# (CONJP (CONJ and)
# (ADJP (ADV very) (ADJ inproper)))
# (PP (P for)
# (NP (D a) (ADJ weake) (N woman)))))))))))
# (, ;)
# (CP-CAR (WPP-3 (WADV+P wherin))
# (C 0)
# (IP-SUB (PP *T*-3)
# (NP-SBJ (PRO I))
# (MD shall)
# (ADVP-TMP (ADV still))
# (DO doo)
# (NP-OB1 (D the)
# (ADJ outmost)
# (CP-REL (WNP-4 0)
# (C that)
# (IP-SUB (NP-SBJ *T*-4)
# (MD shall)
# (VB ley)
# (PP (P in)
# (NP (PRO$ my) (N power))))))))))))))))))))))))
# (. .))
# ( (IP-MAT (CONJ But)
# (NP-VOC (ADJ good) (N Cosin))
# (NP-SBJ (PRO I))
# (BEP am)
# (ADJP (ADJ confident)
# (CP-THT (C 0)
# (IP-SUB (NP-SBJ (PRO you))
# (BEP are)
# (ADJP (ADJP (ADVR so) (ADJ ingenuous))
# (CONJP (CONJ and)
# (PP (P of)
# (NP (QP (ADVR so)
# (Q much)
# (PP *ICH*-1))
# (N iudgement)
# (PP-1 (P as)
# (CP-DEG (C theat)
# (IP-SUB (NP-SBJ (PRO you))
# (MD will)
# (NEG not)
# (VB conceive)
# (CP-THT (C 0)
# (IP-SUB (NP-SBJ (PRO I))
# (MD can)
# (VB soppose)
# (CP-THT (C 0)
# (IP-SUB (NP-SBJ (PRO$ my) (N husband))
# (MD shulld)
# (VB expend)
# (NP-OB1 (PRO$ his) (N esteat))
# (PP (P for)
# (NP (D a)
# (N sonne)
# (PP (P in)
# (NP (N Leaw)))))
# (, ,)
# (IP-PPL (HAG having)
# (NP-OB1 (ONE one)
# (PP (P of)
# (NP (PRO$ his) (ADJ owen)))))
# (, ,)
# (CP-CAR (WNP-2 (WPRO which))
# (C 0)
# (IP-SUB (NP-SBJ (PRO I))
# (VBP doubt)
# (NEG not)
# (CP-THT (C 0)
# (IP-SUB (NP-OB1 *T*-2)
# (NP-SBJ (PRO you))
# (MD will)
# (VB take)
# (PP (P into)
# (NP (ADJP (ADVR so)
# (ADJ serious)
# (PP *ICH*-3))
# (N consideracon)
# (PP-3 (P as)
# (IP-INF-DEG (TO to)
# (VB afforde)
# (NP-OB1 (Q all)
# (ADJ faitherly)
# (N care)
# (CONJP (CONJ and)
# (NX (N affection))))
# (PP (P towards)
# (NP (PRO him)
# (CP-REL (WNP-4 (WPRO who))
# (C 0)
# (IP-SUB (NP-SBJ *T*-4)
# (BEP is)
# (ADVP-TMP (ADV now))
# (VAN made)
# (IP-SMC (NP-SBJ *T*-4)
# (NP-OB1 (PRO$ $your) (N $sonne)))
# (PP (P by)
# (NP (D a)
# (N decre)
# (, ,)
# (CP-EOP (WNP-5 0)
# (IP-INF (NP-SBJ *T*-5)
# (PP (P as)
# (CP-ADV (WNP-6 0)
# (C 0)
# (IP-SUB (NP-OB1 *T*-6)
# (NP-SBJ (PRO you))
# (VBP write)
# (ADVP (ADV very) (ADV truely)))))
# (, ,)
# (NEG not)
# (TO to)
# (BE be)
# (VAN prevented)))))))))))))))))))))))))))))))
# (. :))
# ( (IP-MAT (CONJ and)
# (PP (P for)
# (NP (PRO$ my) (N sellfe)))
# (NP-SBJ (PRO I))
# (MD shall)
# (ADVP-TMP (ADV never))
# (BE be)
# (VAG wanting)
# (IP-INF (NP-MSR (ADJP (ADVR as) (ADJ fare))
# (PP (P as)
# (CP-CMP (WQP-1 0)
# (C 0)
# (IP-SUB (NP-SBJ (PRO I))
# (BEP am)
# (ADJP (QP *T*-1)
# (ADJ able))))))
# (TO to)
# (VB performe)
# (NP-OB1 (D the)
# (N part)
# (PP (P of)
# (NP (D a) (N mother)))))
# (. ,))
# ( (IP-MAT (CONJ and)
# (PP (P for)
# (NP (D the) (ADJ present)))
# (NP-SBJ *con*)
# (MD shall)
# (VB conclude)
# (, ,)
# (PP (P by)
# (NP (PRO$ youer) (ADJ owen) (ADJ good) (N exampele)))
# (, ,)
# (PP (P with)
# (NP (PRO$ my)
# (NS prayers)
# (CP-THT (C that)
# (IP-SUB (NP-SBJ (Q all) (NS blessings))
# (MD meay)
# (BE bee)
# (VAN multyplyed)
# (PP (P opon)
# (NP (PRO thim)
# (QP (Q both))))
# (, ,)
# (CP-CAR (WNP-1 (WPRO which))
# (C 0)
# (IP-SUB (NP-SBJ *T*-1)
# (MD shall)
# (ADVP-TMP (ADV allways))
# (BE bee)
# (NP-OB1 (D the)
# (ADJ fervent)
# (N desier)
# (PP (P of)
# (NP (PRO her)
# (CP-REL (WNP-2 0)
# (C that)
# (IP-SUB (NP-SBJ *T*-2)
# (BEP is)
# (, ,)
# (NP-VOC (ADJ worthy) (N Cosin))
# (, ,)
# (NP-OB1 (PRO$ Youer)
# (ADJ afacnat)
# (N+N kinwomen)
# (CONJP (CONJ and)
# (NX (N sister)))
# (NP-PRN (NPR Zowch)))))))))))))))
# ( (NP-TMP (NPR Setember) (D this) (NUM 28) (NUM 1649))

# %%
clauses={};
counta=0;
clauses[counta]=[];
for token in tokens:
    for line in tokens[token]:
        if 'IP' in line and 'IP-SUB' not in line and 'IP-INF' not in line:
            counta+=1;
            clauses[counta]=[];
        if 'CP' in line:
            counta+=1;
            clauses[counta]=[];
        clauses[counta].append(line);

# %%
jack=re.findall(r'\([A-Za-z0-9_-]*\b',st)

# %%
jack[0].strip('()')
# Out:
# 'IP-MAT'

# %%
clauses
# Out:
# {0: ['( (CODE <P_158>))',
#   '( (CODE <heading:edcomment:XCIX_KATHERINE,_LADY_ZOUCH,_TO_HENRY_OXINDEN>))',
#   '( (CODE {COM:editorial_material_omitted}))'],
#  1: ['( (IP-MAT (NP-VOC (VAN Honored) (N Cosen))',
#   '(, ,)',
#   '(NP-SBJ (PRO I))',
#   '(MD must)',
#   '(VB returne)',
#   '(NP-OB2 (PRO you))',
#   '(NP-OB1 (Q many) (NS thanks))',
#   '(PP (P for)',
#   '(NP (D the)',
#   '(ADJ great)',
#   '(NS payns)',
#   '(CONJP (CONJ and)',
#   '(NX (N care)))',
#   '(, ,)'],
#  2: ['(CP-REL (WNP-1 0)',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ (PRO you))',
#   '(HVP have)',
#   '(BEN bene)',
#   '(VAN pleased)',
#   '(IP-INF (NP-OB1 *T*-1)',
#   '(TO to)',
#   '(VB take)',
#   '(PP (P in)',
#   "(NP (NP-POS (PRO$ my) (N$ sonne's))",
#   '(N bisnes))))))))',
#   '(. .))',
#   '(ID ZOUCH-E3-P2,158.4))'],
#  3: ['( (IP-MAT (NP-SBJ (PRO You))',
#   '(MD will)',
#   '(ADVP-TMP (ADV now))',
#   '(VB continue)',
#   '(PP (P with)',
#   '(NP (D the)',
#   '(ADJP (ADJ seame)',
#   '(CONJP *ICH*-1))',
#   '(N sealle))',
#   '(CODE {COM:zeal})',
#   '(CONJP-1 (CONJ or)',
#   '(NP (ADJR greter))))',
#   '(PP (P in)',
#   '(NP (PRO$ his) (N behalfe)))',
#   '(, ,)',
#   '(PP (P by)',
#   '(NP (N reason)',
#   '(PP (P of)',
#   '(NP (D that)',
#   '(ADJ neerre)',
#   '(N relacond)'],
#  4: ['(CP-REL (WNP-2 (WPRO which))',
#   '(C 0)',
#   '(IP-SUB (NP-OB1 *T*-2)',
#   '(NP-SBJ (PRO you))',
#   '(VBP mention)',
#   '(PP (P in)',
#   '(NP (ADJ youer) (N letter)))))',
#   '(, ,)'],
#  5: ['(CP-REL (WPP-3 (WADV+P wherin))',
#   '(C 0)',
#   '(IP-SUB (PP *T*-3)',
#   '(NP-SBJ (PRO hee))',
#   '(HVP hath)',
#   '(VBN ioyned)',
#   '(NP-OB1 (PRO+N himsellfe))',
#   '(PP (RP on)',
#   '(P to)',
#   '(NP (PRO you)))))))))',
#   '(. :))',
#   '(ID ZOUCH-E3-P2,158.5))'],
#  6: ['( (IP-MAT (NP-OB1 (D the)',
#   '(ADJ first)',
#   '(N intellegenc)',
#   '(PP (ADV+P therof)))',
#   '(NP-SBJ (PRO I))',
#   '(DOD did)',
#   '(VB reseve)',
#   '(PP (P from)',
#   '(NP (PRO$+N youeresellfe)))',
#   '(, ;)'],
#  7: ['(CP-CAR (WPP-1 (WADV+P whereof))',
#   '(C 0)',
#   '(IP-SUB (PP *T*-1)',
#   '(NP-SBJ (PRO I))',
#   '(VBP confes)',
#   '(ADJP-SPR (NP-MSR (Q+WPRO somewhat))',
#   '(ADJ strange)',
#   '(CONJP (CONJ and)',
#   '(ADJX (ADJ onexpected)))',
#   '(PP (P to)',
#   '(NP (PRO mee))))))',
#   '(. ;))',
#   '(ID ZOUCH-E3-P2,158.6))'],
#  8: ['( (IP-MAT (CONJ butt)',
#   '(ADVP-TMP (ADV now))',
#   '(, ,)',
#   '(PP-LFD (P though)'],
#  9: ['(CP-ADV (C 0)',
#   '(IP-SUB (NP-SBJ (PRO I))',
#   '(MD $can)',
#   '(NEG $not)',
#   '(CODE {TEXT:canot})',
#   '(BE bee)',
#   '(ADJP (ADJ unsensible)'],
#  10: ['(CP-THT (C that)',
#   '(IP-SUB (NP-SBJ (PRO hee))',
#   '(HVP hath)',
#   '(VBN furgotten)',
#   '(NP-OB1 (PRO mee)',
#   '(NP-PRN (PRO$ his) (N mother)))',
#   '(PP (P in)'],
#  11: ['(IP-PPL (NEG not)',
#   '(VAG takeng)',
#   '(NP-OB1 (PRO$ my) (N advise))',
#   '(PP (P in)',
#   '(NP (D a)',
#   '(N meatter)',
#   '(PP (P of)',
#   '(NP (D that) (N weight)))))))))))))',
#   '(, ,)',
#   '(ADVP-RSP (ADV yet))',
#   '(NP-SBJ (PRO I))',
#   '(BEP am)',
#   '(ADJP (ADJ $glad)'],
#  12: ['(CP-THT (C that)',
#   '(IP-SUB (NP-SBJ (PRO hee))',
#   '(HVP heath)',
#   '(NEG not)',
#   '(VBN furgutten)',
#   '(NP-OB1 (PRO+N himsellfe))',
#   '(PP (P in)',
#   '(NP (PRO$ his) (N Choyce)))',
#   '(, ,)'],
#  13: ['(IP-PPL (HAG haveing)',
#   '(VBN matched)',
#   '(PP (P with)',
#   '(NP (D a)',
#   '(N daughter)',
#   '(PP (P of)',
#   '(NP (PRO$ youers)))'],
#  14: ['(CP-REL (WNP-1 (WPRO$ whose)',
#   '(N worth)',
#   '(CONJP (CONJ and)',
#   '(NX (NS abilityes))))',
#   '(C 0)',
#   '(IP-SUB (NP-OB1 *T*-1)',
#   '(NP-SBJ (PRO I))',
#   '(VBP knowe)',
#   '(ADVP (ADVR so)',
#   '(ADV well)',
#   '(, ,)',
#   '(PP (P as)'],
#  15: ['(CP-DEG (C that)',
#   '(IP-SUB (NP-SBJ (PRO you))',
#   '(BEP are)',
#   '(ADJP (ADJ able)',
#   '(IP-INF (IP-INF (PP (P with)',
#   '(NP (N ease)))',
#   '(TO to)',
#   '(VB assiste)',
#   '(NP-OB1 (PRO him)))',
#   '(CONJP (CONJ and)',
#   '(IP-INF (TO *)',
#   '(VB goe)',
#   '(RP thorwgh)',
#   '(PP (P in)',
#   '(NP (D the)',
#   '(N recovery)',
#   '(PP (P of)',
#   '(NP (PRO$ his) (N esteate)))'],
#  16: ['(CP-REL (WNP-2 (WPRO which))',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ (PRO I))',
#   '(VBP confes)',
#   '(CODE <P_159>)'],
#  17: ['(CP-THT (C 0)',
#   '(IP-SUB (NP-SBJ *T*-2)',
#   '(BED was)',
#   '(NP-OB1 (D a)',
#   '(N taske)',
#   '(ADJP (ADJP (NP-MSR (Q+WPRO somewhat))',
#   '(ADVR to)',
#   '(ADJ heard))',
#   '(CONJP (CONJ and)',
#   '(ADJP (ADV very) (ADJ inproper)))',
#   '(PP (P for)',
#   '(NP (D a) (ADJ weake) (N woman)))))))))))',
#   '(, ;)'],
#  18: ['(CP-CAR (WPP-3 (WADV+P wherin))',
#   '(C 0)',
#   '(IP-SUB (PP *T*-3)',
#   '(NP-SBJ (PRO I))',
#   '(MD shall)',
#   '(ADVP-TMP (ADV still))',
#   '(DO doo)',
#   '(NP-OB1 (D the)',
#   '(ADJ outmost)'],
#  19: ['(CP-REL (WNP-4 0)',
#   '(C that)',
#   '(IP-SUB (NP-SBJ *T*-4)',
#   '(MD shall)',
#   '(VB ley)',
#   '(PP (P in)',
#   '(NP (PRO$ my) (N power))))))))))))))))))))))))',
#   '(. .))',
#   '(ID ZOUCH-E3-P2,159.7))'],
#  20: ['( (IP-MAT (CONJ But)',
#   '(NP-VOC (ADJ good) (N Cosin))',
#   '(NP-SBJ (PRO I))',
#   '(BEP am)',
#   '(ADJP (ADJ confident)'],
#  21: ['(CP-THT (C 0)',
#   '(IP-SUB (NP-SBJ (PRO you))',
#   '(BEP are)',
#   '(ADJP (ADJP (ADVR so) (ADJ ingenuous))',
#   '(CONJP (CONJ and)',
#   '(PP (P of)',
#   '(NP (QP (ADVR so)',
#   '(Q much)',
#   '(PP *ICH*-1))',
#   '(N iudgement)',
#   '(PP-1 (P as)'],
#  22: ['(CP-DEG (C theat)',
#   '(IP-SUB (NP-SBJ (PRO you))',
#   '(MD will)',
#   '(NEG not)',
#   '(VB conceive)'],
#  23: ['(CP-THT (C 0)', '(IP-SUB (NP-SBJ (PRO I))', '(MD can)', '(VB soppose)'],
#  24: ['(CP-THT (C 0)',
#   '(IP-SUB (NP-SBJ (PRO$ my) (N husband))',
#   '(MD shulld)',
#   '(VB expend)',
#   '(NP-OB1 (PRO$ his) (N esteat))',
#   '(PP (P for)',
#   '(NP (D a)',
#   '(N sonne)',
#   '(PP (P in)',
#   '(NP (N Leaw)))))',
#   '(, ,)'],
#  25: ['(IP-PPL (HAG having)',
#   '(NP-OB1 (ONE one)',
#   '(PP (P of)',
#   '(NP (PRO$ his) (ADJ owen)))))',
#   '(, ,)'],
#  26: ['(CP-CAR (WNP-2 (WPRO which))',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ (PRO I))',
#   '(VBP doubt)',
#   '(NEG not)'],
#  27: ['(CP-THT (C 0)',
#   '(IP-SUB (NP-OB1 *T*-2)',
#   '(NP-SBJ (PRO you))',
#   '(MD will)',
#   '(VB take)',
#   '(PP (P into)',
#   '(NP (ADJP (ADVR so)',
#   '(ADJ serious)',
#   '(PP *ICH*-3))',
#   '(N consideracon)',
#   '(PP-3 (P as)',
#   '(IP-INF-DEG (TO to)',
#   '(VB afforde)',
#   '(NP-OB1 (Q all)',
#   '(ADJ faitherly)',
#   '(N care)',
#   '(CONJP (CONJ and)',
#   '(NX (N affection))))',
#   '(PP (P towards)',
#   '(NP (PRO him)'],
#  28: ['(CP-REL (WNP-4 (WPRO who))',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ *T*-4)',
#   '(BEP is)',
#   '(ADVP-TMP (ADV now))',
#   '(VAN made)'],
#  29: ['(IP-SMC (NP-SBJ *T*-4)',
#   '(NP-OB1 (PRO$ $your) (N $sonne)))',
#   '(PP (P by)',
#   '(NP (D a)',
#   '(N decre)',
#   '(, ,)'],
#  30: ['(CP-EOP (WNP-5 0)', '(IP-INF (NP-SBJ *T*-5)', '(PP (P as)'],
#  31: ['(CP-ADV (WNP-6 0)',
#   '(C 0)',
#   '(IP-SUB (NP-OB1 *T*-6)',
#   '(NP-SBJ (PRO you))',
#   '(VBP write)',
#   '(ADVP (ADV very) (ADV truely)))))',
#   '(, ,)',
#   '(NEG not)',
#   '(TO to)',
#   '(BE be)',
#   '(VAN prevented)))))))))))))))))))))))))))))))',
#   '(. :))',
#   '(ID ZOUCH-E3-P2,159.8))'],
#  32: ['( (IP-MAT (CONJ and)',
#   '(PP (P for)',
#   '(NP (PRO$ my) (N sellfe)))',
#   '(NP-SBJ (PRO I))',
#   '(MD shall)',
#   '(ADVP-TMP (ADV never))',
#   '(BE be)',
#   '(VAG wanting)',
#   '(IP-INF (NP-MSR (ADJP (ADVR as) (ADJ fare))',
#   '(PP (P as)'],
#  33: ['(CP-CMP (WQP-1 0)',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ (PRO I))',
#   '(BEP am)',
#   '(ADJP (QP *T*-1)',
#   '(ADJ able))))))',
#   '(TO to)',
#   '(VB performe)',
#   '(NP-OB1 (D the)',
#   '(N part)',
#   '(PP (P of)',
#   '(NP (D a) (N mother)))))',
#   '(. ,))',
#   '(ID ZOUCH-E3-P2,159.9))'],
#  34: ['( (IP-MAT (CONJ and)',
#   '(PP (P for)',
#   '(NP (D the) (ADJ present)))',
#   '(NP-SBJ *con*)',
#   '(MD shall)',
#   '(VB conclude)',
#   '(, ,)',
#   '(PP (P by)',
#   '(NP (PRO$ youer) (ADJ owen) (ADJ good) (N exampele)))',
#   '(, ,)',
#   '(PP (P with)',
#   '(NP (PRO$ my)',
#   '(NS prayers)'],
#  35: ['(CP-THT (C that)',
#   '(IP-SUB (NP-SBJ (Q all) (NS blessings))',
#   '(MD meay)',
#   '(BE bee)',
#   '(VAN multyplyed)',
#   '(PP (P opon)',
#   '(NP (PRO thim)',
#   '(QP (Q both))))',
#   '(, ,)'],
#  36: ['(CP-CAR (WNP-1 (WPRO which))',
#   '(C 0)',
#   '(IP-SUB (NP-SBJ *T*-1)',
#   '(MD shall)',
#   '(ADVP-TMP (ADV allways))',
#   '(BE bee)',
#   '(NP-OB1 (D the)',
#   '(ADJ fervent)',
#   '(N desier)',
#   '(PP (P of)',
#   '(NP (PRO her)'],
#  37: ['(CP-REL (WNP-2 0)',
#   '(C that)',
#   '(IP-SUB (NP-SBJ *T*-2)',
#   '(BEP is)',
#   '(, ,)',
#   '(NP-VOC (ADJ worthy) (N Cosin))',
#   '(, ,)',
#   '(NP-OB1 (PRO$ Youer)',
#   '(ADJ afacnat)',
#   '(N+N kinwomen)',
#   '(CONJP (CONJ and)',
#   '(NX (N sister)))',
#   '(NP-PRN (NPR Zowch)))))))))))))))',
#   '(ID ZOUCH-E3-P2,159.10))',
#   '( (CODE {COM:postscript_omitted}))',
#   '( (NP-TMP (NPR Setember) (D this) (NUM 28) (NUM 1649))',
#   '(ID ZOUCH-E3-P2,159.12))']}

# %%
words={};
for line in bob[0]:
    words[line]=[];
    jack=re.findall(r'\b[A-Za-z\']*\)',line)
    print(jack)
    words[line].append(jack)
# Out:
# []
# []
# []
# ['Honored)', 'Cosen)']
# []
# ['I)']
# ['must)']
# ['returne)']
# ['you)']
# ['many)', 'thanks)']
# ['for)']
# ['the)']
# ['great)']
# ['payns)']
# ['and)']
# ['care)']
# []
# [')']
# [')']
# ['you)']
# ['have)']
# ['bene)']
# ['pleased)']
# [')']
# ['to)']
# ['take)']
# ['in)']
# ['my)', "sonne's)"]
# ['bisnes)']
# []
# [')']
# ['You)']
# ['will)']
# ['now)']
# ['continue)']
# ['with)']
# ['the)']
# ['seame)']
# [')']
# ['sealle)']
# []
# ['or)']
# ['greter)']
# ['in)']
# ['his)', 'behalfe)']
# []
# ['by)']
# ['reason)']
# ['of)']
# ['that)']
# ['neerre)']
# ['relacond)']
# ['which)']
# [')']
# [')']
# ['you)']
# ['mention)']
# ['in)']
# ['youer)', 'letter)']
# []
# ['wherin)']
# [')']
# [')']
# ['hee)']
# ['hath)']
# ['ioyned)']
# ['himsellfe)']
# ['on)']
# ['to)']
# ['you)']
# []
# [')']
# ['the)']
# ['first)']
# ['intellegenc)']
# ['therof)']
# ['I)']
# ['did)']
# ['reseve)']
# ['from)']
# ['youeresellfe)']
# []
# ['whereof)']
# [')']
# [')']
# ['I)']
# ['confes)']
# ['somewhat)']
# ['strange)']
# ['and)']
# ['onexpected)']
# ['to)']
# ['mee)']
# []
# [')']
# ['butt)']
# ['now)']
# []
# ['though)']
# [')']
# ['I)']
# ['can)']
# ['not)']
# []
# ['bee)']
# ['unsensible)']
# ['that)']
# ['hee)']
# ['hath)']
# ['furgotten)']
# ['mee)']
# ['his)', 'mother)']
# ['in)']
# ['not)']
# ['takeng)']
# ['my)', 'advise)']
# ['in)']
# ['a)']
# ['meatter)']
# ['of)']
# ['that)', 'weight)']
# []
# ['yet)']
# ['I)']
# ['am)']
# ['glad)']
# ['that)']
# ['hee)']
# ['heath)']
# ['not)']
# ['furgutten)']
# ['himsellfe)']
# ['in)']
# ['his)', 'Choyce)']
# []
# ['haveing)']
# ['matched)']
# ['with)']
# ['a)']
# ['daughter)']
# ['of)']
# ['youers)']
# ['whose)']
# ['worth)']
# ['and)']
# ['abilityes)']
# [')']
# [')']
# ['I)']
# ['knowe)']
# ['so)']
# ['well)']
# []
# ['as)']
# ['that)']
# ['you)']
# ['are)']
# ['able)']
# ['with)']
# ['ease)']
# ['to)']
# ['assiste)']
# ['him)']
# ['and)']
# []
# ['goe)']
# ['thorwgh)']
# ['in)']
# ['the)']
# ['recovery)']
# ['of)']
# ['his)', 'esteate)']
# ['which)']
# [')']
# ['I)']
# ['confes)']
# []
# [')']
# [')']
# ['was)']
# ['a)']
# ['taske)']
# ['somewhat)']
# ['to)']
# ['heard)']
# ['and)']
# ['very)', 'inproper)']
# ['for)']
# ['a)', 'weake)', 'woman)']
# []
# ['wherin)']
# [')']
# [')']
# ['I)']
# ['shall)']
# ['still)']
# ['doo)']
# ['the)']
# ['outmost)']
# [')']
# ['that)']
# [')']
# ['shall)']
# ['ley)']
# ['in)']
# ['my)', 'power)']
# []
# [')']
# ['But)']
# ['good)', 'Cosin)']
# ['I)']
# ['am)']
# ['confident)']
# [')']
# ['you)']
# ['are)']
# ['so)', 'ingenuous)']
# ['and)']
# ['of)']
# ['so)']
# ['much)']
# [')']
# ['iudgement)']
# ['as)']
# ['theat)']
# ['you)']
# ['will)']
# ['not)']
# ['conceive)']
# [')']
# ['I)']
# ['can)']
# ['soppose)']
# [')']
# ['my)', 'husband)']
# ['shulld)']
# ['expend)']
# ['his)', 'esteat)']
# ['for)']
# ['a)']
# ['sonne)']
# ['in)']
# ['Leaw)']
# []
# ['having)']
# ['one)']
# ['of)']
# ['his)', 'owen)']
# []
# ['which)']
# [')']
# ['I)']
# ['doubt)']
# ['not)']
# [')']
# [')']
# ['you)']
# ['will)']
# ['take)']
# ['into)']
# ['so)']
# ['serious)']
# [')']
# ['consideracon)']
# ['as)']
# ['to)']
# ['afforde)']
# ['all)']
# ['faitherly)']
# ['care)']
# ['and)']
# ['affection)']
# ['towards)']
# ['him)']
# ['who)']
# [')']
# [')']
# ['is)']
# ['now)']
# ['made)']
# [')']
# ['your)', 'sonne)']
# ['by)']
# ['a)']
# ['decre)']
# []
# [')']
# [')']
# ['as)']
# [')']
# [')']
# [')']
# ['you)']
# ['write)']
# ['very)', 'truely)']
# []
# ['not)']
# ['to)']
# ['be)']
# ['prevented)']
# []
# [')']
# ['and)']
# ['for)']
# ['my)', 'sellfe)']
# ['I)']
# ['shall)']
# ['never)']
# ['be)']
# ['wanting)']
# ['as)', 'fare)']
# ['as)']
# [')']
# [')']
# ['I)']
# ['am)']
# [')']
# ['able)']
# ['to)']
# ['performe)']
# ['the)']
# ['part)']
# ['of)']
# ['a)', 'mother)']
# []
# [')']
# ['and)']
# ['for)']
# ['the)', 'present)']
# []
# ['shall)']
# ['conclude)']
# []
# ['by)']
# ['youer)', 'owen)', 'good)', 'exampele)']
# []
# ['with)']
# ['my)']
# ['prayers)']
# ['that)']
# ['all)', 'blessings)']
# ['meay)']
# ['bee)']
# ['multyplyed)']
# ['opon)']
# ['thim)']
# ['both)']
# []
# ['which)']
# [')']
# [')']
# ['shall)']
# ['allways)']
# ['bee)']
# ['the)']
# ['fervent)']
# ['desier)']
# ['of)']
# ['her)']
# [')']
# ['that)']
# [')']
# ['is)']
# []
# ['worthy)', 'Cosin)']
# []
# ['Youer)']
# ['afacnat)']
# ['kinwomen)']
# ['and)']
# ['sister)']
# ['Zowch)']
# [')']
# []
# ['Setember)', 'this)', ')', ')']
# [')']

# %%
words
# Out:
# {'( (CODE <P_158>))': [[]],
#  '( (CODE <heading:edcomment:XCIX_KATHERINE,_LADY_ZOUCH,_TO_HENRY_OXINDEN>))': [[]],
#  '( (CODE {COM:editorial_material_omitted}))': [[]],
#  '( (IP-MAT (NP-VOC (VAN Honored) (N Cosen))': [['Honored)', 'Cosen)']],
#  '(, ,)': [[]],
#  '(NP-SBJ (PRO I))': [['I)']],
#  '(MD must)': [['must)']],
#  '(VB returne)': [['returne)']],
#  '(NP-OB2 (PRO you))': [['you)']],
#  '(NP-OB1 (Q many) (NS thanks))': [['many)', 'thanks)']],
#  '(PP (P for)': [['for)']],
#  '(NP (D the)': [['the)']],
#  '(ADJ great)': [['great)']],
#  '(NS payns)': [['payns)']],
#  '(CONJP (CONJ and)': [['and)']],
#  '(NX (N care)))': [['care)']],
#  '(CP-REL (WNP-1 0)': [['0)']],
#  '(C 0)': [['0)']],
#  '(IP-SUB (NP-SBJ (PRO you))': [['you)']],
#  '(HVP have)': [['have)']],
#  '(BEN bene)': [['bene)']],
#  '(VAN pleased)': [['pleased)']],
#  '(IP-INF (NP-OB1 *T*-1)': [['1)']],
#  '(TO to)': [['to)']],
#  '(VB take)': [['take)']],
#  '(PP (P in)': [['in)']],
#  "(NP (NP-POS (PRO$ my) (N$ sonne's))": [['my)', 's)']],
#  '(N bisnes))))))))': [['bisnes)']],
#  '(. .))': [[]],
#  '(ID ZOUCH-E3-P2,158.4))': [['4)']],
#  '( (IP-MAT (NP-SBJ (PRO You))': [['You)']],
#  '(MD will)': [['will)']],
#  '(ADVP-TMP (ADV now))': [['now)']],
#  '(VB continue)': [['continue)']],
#  '(PP (P with)': [['with)']],
#  '(ADJP (ADJ seame)': [['seame)']],
#  '(CONJP *ICH*-1))': [['1)']],
#  '(N sealle))': [['sealle)']],
#  '(CODE {COM:zeal})': [[]],
#  '(CONJP-1 (CONJ or)': [['or)']],
#  '(NP (ADJR greter))))': [['greter)']],
#  '(NP (PRO$ his) (N behalfe)))': [['his)', 'behalfe)']],
#  '(PP (P by)': [['by)']],
#  '(NP (N reason)': [['reason)']],
#  '(PP (P of)': [['of)']],
#  '(NP (D that)': [['that)']],
#  '(ADJ neerre)': [['neerre)']],
#  '(N relacond)': [['relacond)']],
#  '(CP-REL (WNP-2 (WPRO which))': [['which)']],
#  '(IP-SUB (NP-OB1 *T*-2)': [['2)']],
#  '(NP-SBJ (PRO you))': [['you)']],
#  '(VBP mention)': [['mention)']],
#  '(NP (ADJ youer) (N letter)))))': [['youer)', 'letter)']],
#  '(CP-REL (WPP-3 (WADV+P wherin))': [['wherin)']],
#  '(IP-SUB (PP *T*-3)': [['3)']],
#  '(NP-SBJ (PRO hee))': [['hee)']],
#  '(HVP hath)': [['hath)']],
#  '(VBN ioyned)': [['ioyned)']],
#  '(NP-OB1 (PRO+N himsellfe))': [['himsellfe)']],
#  '(PP (RP on)': [['on)']],
#  '(P to)': [['to)']],
#  '(NP (PRO you)))))))))': [['you)']],
#  '(. :))': [[]],
#  '(ID ZOUCH-E3-P2,158.5))': [['5)']],
#  '( (IP-MAT (NP-OB1 (D the)': [['the)']],
#  '(ADJ first)': [['first)']],
#  '(N intellegenc)': [['intellegenc)']],
#  '(PP (ADV+P therof)))': [['therof)']],
#  '(DOD did)': [['did)']],
#  '(VB reseve)': [['reseve)']],
#  '(PP (P from)': [['from)']],
#  '(NP (PRO$+N youeresellfe)))': [['youeresellfe)']],
#  '(, ;)': [[]],
#  '(CP-CAR (WPP-1 (WADV+P whereof))': [['whereof)']],
#  '(IP-SUB (PP *T*-1)': [['1)']],
#  '(VBP confes)': [['confes)']],
#  '(ADJP-SPR (NP-MSR (Q+WPRO somewhat))': [['somewhat)']],
#  '(ADJ strange)': [['strange)']],
#  '(ADJX (ADJ onexpected)))': [['onexpected)']],
#  '(PP (P to)': [['to)']],
#  '(NP (PRO mee))))))': [['mee)']],
#  '(. ;))': [[]],
#  '(ID ZOUCH-E3-P2,158.6))': [['6)']],
#  '( (IP-MAT (CONJ butt)': [['butt)']],
#  '(PP-LFD (P though)': [['though)']],
#  '(CP-ADV (C 0)': [['0)']],
#  '(IP-SUB (NP-SBJ (PRO I))': [['I)']],
#  '(MD $can)': [['can)']],
#  '(NEG $not)': [['not)']],
#  '(CODE {TEXT:canot})': [[]],
#  '(BE bee)': [['bee)']],
#  '(ADJP (ADJ unsensible)': [['unsensible)']],
#  '(CP-THT (C that)': [['that)']],
#  '(IP-SUB (NP-SBJ (PRO hee))': [['hee)']],
#  '(VBN furgotten)': [['furgotten)']],
#  '(NP-OB1 (PRO mee)': [['mee)']],
#  '(NP-PRN (PRO$ his) (N mother)))': [['his)', 'mother)']],
#  '(IP-PPL (NEG not)': [['not)']],
#  '(VAG takeng)': [['takeng)']],
#  '(NP-OB1 (PRO$ my) (N advise))': [['my)', 'advise)']],
#  '(NP (D a)': [['a)']],
#  '(N meatter)': [['meatter)']],
#  '(NP (D that) (N weight)))))))))))))': [['that)', 'weight)']],
#  '(ADVP-RSP (ADV yet))': [['yet)']],
#  '(BEP am)': [['am)']],
#  '(ADJP (ADJ $glad)': [['glad)']],
#  '(HVP heath)': [['heath)']],
#  '(NEG not)': [['not)']],
#  '(VBN furgutten)': [['furgutten)']],
#  '(NP (PRO$ his) (N Choyce)))': [['his)', 'Choyce)']],
#  '(IP-PPL (HAG haveing)': [['haveing)']],
#  '(VBN matched)': [['matched)']],
#  '(N daughter)': [['daughter)']],
#  '(NP (PRO$ youers)))': [['youers)']],
#  '(CP-REL (WNP-1 (WPRO$ whose)': [['whose)']],
#  '(N worth)': [['worth)']],
#  '(NX (NS abilityes))))': [['abilityes)']],
#  '(IP-SUB (NP-OB1 *T*-1)': [['1)']],
#  '(VBP knowe)': [['knowe)']],
#  '(ADVP (ADVR so)': [['so)']],
#  '(ADV well)': [['well)']],
#  '(PP (P as)': [['as)']],
#  '(CP-DEG (C that)': [['that)']],
#  '(BEP are)': [['are)']],
#  '(ADJP (ADJ able)': [['able)']],
#  '(IP-INF (IP-INF (PP (P with)': [['with)']],
#  '(NP (N ease)))': [['ease)']],
#  '(VB assiste)': [['assiste)']],
#  '(NP-OB1 (PRO him)))': [['him)']],
#  '(IP-INF (TO *)': [[]],
#  '(VB goe)': [['goe)']],
#  '(RP thorwgh)': [['thorwgh)']],
#  '(N recovery)': [['recovery)']],
#  '(NP (PRO$ his) (N esteate)))': [['his)', 'esteate)']],
#  '(CODE <P_159>)': [[]],
#  '(CP-THT (C 0)': [['0)']],
#  '(IP-SUB (NP-SBJ *T*-2)': [['2)']],
#  '(BED was)': [['was)']],
#  '(NP-OB1 (D a)': [['a)']],
#  '(N taske)': [['taske)']],
#  '(ADJP (ADJP (NP-MSR (Q+WPRO somewhat))': [['somewhat)']],
#  '(ADVR to)': [['to)']],
#  '(ADJ heard))': [['heard)']],
#  '(ADJP (ADV very) (ADJ inproper)))': [['very)', 'inproper)']],
#  '(NP (D a) (ADJ weake) (N woman)))))))))))': [['a)', 'weake)', 'woman)']],
#  '(CP-CAR (WPP-3 (WADV+P wherin))': [['wherin)']],
#  '(MD shall)': [['shall)']],
#  '(ADVP-TMP (ADV still))': [['still)']],
#  '(DO doo)': [['doo)']],
#  '(NP-OB1 (D the)': [['the)']],
#  '(ADJ outmost)': [['outmost)']],
#  '(CP-REL (WNP-4 0)': [['0)']],
#  '(C that)': [['that)']],
#  '(IP-SUB (NP-SBJ *T*-4)': [['4)']],
#  '(VB ley)': [['ley)']],
#  '(NP (PRO$ my) (N power))))))))))))))))))))))))': [['my)', 'power)']],
#  '(ID ZOUCH-E3-P2,159.7))': [['7)']],
#  '( (IP-MAT (CONJ But)': [['But)']],
#  '(NP-VOC (ADJ good) (N Cosin))': [['good)', 'Cosin)']],
#  '(ADJP (ADJ confident)': [['confident)']],
#  '(ADJP (ADJP (ADVR so) (ADJ ingenuous))': [['so)', 'ingenuous)']],
#  '(NP (QP (ADVR so)': [['so)']],
#  '(Q much)': [['much)']],
#  '(PP *ICH*-1))': [['1)']],
#  '(N iudgement)': [['iudgement)']],
#  '(PP-1 (P as)': [['as)']],
#  '(CP-DEG (C theat)': [['theat)']],
#  '(VB conceive)': [['conceive)']],
#  '(MD can)': [['can)']],
#  '(VB soppose)': [['soppose)']],
#  '(IP-SUB (NP-SBJ (PRO$ my) (N husband))': [['my)', 'husband)']],
#  '(MD shulld)': [['shulld)']],
#  '(VB expend)': [['expend)']],
#  '(NP-OB1 (PRO$ his) (N esteat))': [['his)', 'esteat)']],
#  '(N sonne)': [['sonne)']],
#  '(NP (N Leaw)))))': [['Leaw)']],
#  '(IP-PPL (HAG having)': [['having)']],
#  '(NP-OB1 (ONE one)': [['one)']],
#  '(NP (PRO$ his) (ADJ owen)))))': [['his)', 'owen)']],
#  '(CP-CAR (WNP-2 (WPRO which))': [['which)']],
#  '(VBP doubt)': [['doubt)']],
#  '(PP (P into)': [['into)']],
#  '(NP (ADJP (ADVR so)': [['so)']],
#  '(ADJ serious)': [['serious)']],
#  '(PP *ICH*-3))': [['3)']],
#  '(N consideracon)': [['consideracon)']],
#  '(PP-3 (P as)': [['as)']],
#  '(IP-INF-DEG (TO to)': [['to)']],
#  '(VB afforde)': [['afforde)']],
#  '(NP-OB1 (Q all)': [['all)']],
#  '(ADJ faitherly)': [['faitherly)']],
#  '(N care)': [['care)']],
#  '(NX (N affection))))': [['affection)']],
#  '(PP (P towards)': [['towards)']],
#  '(NP (PRO him)': [['him)']],
#  '(CP-REL (WNP-4 (WPRO who))': [['who)']],
#  '(BEP is)': [['is)']],
#  '(VAN made)': [['made)']],
#  '(IP-SMC (NP-SBJ *T*-4)': [['4)']],
#  '(NP-OB1 (PRO$ $your) (N $sonne)))': [['your)', 'sonne)']],
#  '(N decre)': [['decre)']],
#  '(CP-EOP (WNP-5 0)': [['0)']],
#  '(IP-INF (NP-SBJ *T*-5)': [['5)']],
#  '(CP-ADV (WNP-6 0)': [['0)']],
#  '(IP-SUB (NP-OB1 *T*-6)': [['6)']],
#  '(VBP write)': [['write)']],
#  '(ADVP (ADV very) (ADV truely)))))': [['very)', 'truely)']],
#  '(BE be)': [['be)']],
#  '(VAN prevented)))))))))))))))))))))))))))))))': [['prevented)']],
#  '(ID ZOUCH-E3-P2,159.8))': [['8)']],
#  '( (IP-MAT (CONJ and)': [['and)']],
#  '(NP (PRO$ my) (N sellfe)))': [['my)', 'sellfe)']],
#  '(ADVP-TMP (ADV never))': [['never)']],
#  '(VAG wanting)': [['wanting)']],
#  '(IP-INF (NP-MSR (ADJP (ADVR as) (ADJ fare))': [['as)', 'fare)']],
#  '(CP-CMP (WQP-1 0)': [['0)']],
#  '(ADJP (QP *T*-1)': [['1)']],
#  '(ADJ able))))))': [['able)']],
#  '(VB performe)': [['performe)']],
#  '(N part)': [['part)']],
#  '(NP (D a) (N mother)))))': [['a)', 'mother)']],
#  '(. ,))': [[]],
#  '(ID ZOUCH-E3-P2,159.9))': [['9)']],
#  '(NP (D the) (ADJ present)))': [['the)', 'present)']],
#  '(NP-SBJ *con*)': [[]],
#  '(VB conclude)': [['conclude)']],
#  '(NP (PRO$ youer) (ADJ owen) (ADJ good) (N exampele)))': [['youer)',
#    'owen)',
#    'good)',
#    'exampele)']],
#  '(NP (PRO$ my)': [['my)']],
#  '(NS prayers)': [['prayers)']],
#  '(IP-SUB (NP-SBJ (Q all) (NS blessings))': [['all)', 'blessings)']],
#  '(MD meay)': [['meay)']],
#  '(VAN multyplyed)': [['multyplyed)']],
#  '(PP (P opon)': [['opon)']],
#  '(NP (PRO thim)': [['thim)']],
#  '(QP (Q both))))': [['both)']],
#  '(CP-CAR (WNP-1 (WPRO which))': [['which)']],
#  '(IP-SUB (NP-SBJ *T*-1)': [['1)']],
#  '(ADVP-TMP (ADV allways))': [['allways)']],
#  '(ADJ fervent)': [['fervent)']],
#  '(N desier)': [['desier)']],
#  '(NP (PRO her)': [['her)']],
#  '(CP-REL (WNP-2 0)': [['0)']],
#  '(NP-VOC (ADJ worthy) (N Cosin))': [['worthy)', 'Cosin)']],
#  '(NP-OB1 (PRO$ Youer)': [['Youer)']],
#  '(ADJ afacnat)': [['afacnat)']],
#  '(N+N kinwomen)': [['kinwomen)']],
#  '(NX (N sister)))': [['sister)']],
#  '(NP-PRN (NPR Zowch)))))))))))))))': [['Zowch)']],
#  '(ID ZOUCH-E3-P2,159.10))': [['10)']],
#  '( (CODE {COM:postscript_omitted}))': [[]],
#  '( (NP-TMP (NPR Setember) (D this) (NUM 28) (NUM 1649))': [['Setember)',
#    'this)',
#    '28)',
#    '1649)']],
#  '(ID ZOUCH-E3-P2,159.12))': [['12)']]}

# %%
ptext=re.findall(r'\b[A-Za-z\']*\)',str(bob[0][:]))

# %%
f= open("guru99.txt","w+")
for i in ptext:
     f.write(i.strip("()")+' ')
f.close()
