# %%
bob=open('zouch-e3-p2.psd','r')

# %%
bob.readlines()
# Out:
# ['( (CODE <P_158>))\n',
#  '\n',
#  '( (CODE <heading:edcomment:XCIX_KATHERINE,_LADY_ZOUCH,_TO_HENRY_OXINDEN>))\n',
#  '\n',
#  '( (CODE {COM:editorial_material_omitted}))\n',
#  '\n',
#  '( (IP-MAT (NP-VOC (VAN Honored) (N Cosen))\n',
#  '\t  (, ,)\n',
#  '\t  (NP-SBJ (PRO I))\n',
#  '\t  (MD must)\n',
#  '\t  (VB returne)\n',
#  '\t  (NP-OB2 (PRO you))\n',
#  '\t  (NP-OB1 (Q many) (NS thanks))\n',
#  '\t  (PP (P for)\n',
#  '\t      (NP (D the)\n',
#  '\t\t  (ADJ great)\n',
#  '\t\t  (NS payns)\n',
#  '\t\t  (CONJP (CONJ and)\n',
#  '\t\t\t (NX (N care)))\n',
#  '\t\t  (, ,)\n',
#  '\t\t  (CP-REL (WNP-1 0)\n',
#  '\t\t\t  (C 0)\n',
#  '\t\t\t  (IP-SUB (NP-SBJ (PRO you))\n',
#  '\t\t\t\t  (HVP have)\n',
#  '\t\t\t\t  (BEN bene)\n',
#  '\t\t\t\t  (VAN pleased)\n',
#  '\t\t\t\t  (IP-INF (NP-OB1 *T*-1)\n',
#  '\t\t\t\t\t  (TO to)\n',
#  '\t\t\t\t\t  (VB take)\n',
#  '\t\t\t\t\t  (PP (P in)\n',
#  "\t\t\t\t\t      (NP (NP-POS (PRO$ my) (N$ sonne's))\n",
# ...

# %%
import(csv)
# Out:
#   File "<ipython-input-8-1ec91a0fc2e8>", line 1
#     import(csv)
#           ^
# SyntaxError: invalid syntax

# %%
import csv

# %%
with open('zouch-e3-p2.psd', 'r') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
            print ', '.join(row)
# Out:
#   File "<ipython-input-13-5a722228fd35>", line 4
#     print ', '.join(row)
#              ^
# SyntaxError: invalid syntax
